# %% [markdown]
# # 05. Quantum Convolution Depth Ablation (L = 1..5)
# Ablation study analyzing accuracy and parameter trends across quantum convolution depths.

# %%
import sys
sys.path.append('../src')

# !python ../scripts/run_ablation.py --smoke

# %%
import pandas as pd
from IPython.display import display
df = pd.read_csv('../outputs/ablation/metrics/depth_ablation.csv')
display(df)
