# %% [markdown]
# # 03. Indian Pines Development Benchmark Training
# Train QueenNet on Indian Pines dataset subset and visualize metrics.

# %%
import sys
sys.path.append('../src')

from queennet.config import load_config
from queennet.seed import set_seed
set_seed(42)
print('Deterministic environment configured.')

# %%
# Run training via python script
# !python ../scripts/train.py --config ../configs/indian_pines.yaml --smoke
# !python ../scripts/evaluate.py --config ../configs/indian_pines.yaml
